# %%
from IPython.display import Image
Image('Fcc.JPG')

# %%
import jupyterthemes

# %%
jupyterthemes.get_themes()
jupyterthemes.stylefx.set_nb_theme( 'gruvboxd')
# Out:
# <style> div#notebook {
#  font-family: sans-serif;
#  font-size: 13pt;
#  line-height: 170%;
#  color: #ebdbb2;
#  -webkit-font-smoothing: antialiased !important;
#  padding-top: 25px !important;
# }
# body,
# div.body {
#  font-family: sans-serif;
#  font-size: 13pt;
#  color: #ebdbb2;
#  background-color: #1d2021;
#  background: #1d2021;
#  -webkit-font-smoothing: antialiased !important;
# }
# body.notebook_app {
#  padding: 0;
#  background-color: #1d2021;
#  background: #1d2021;
#  padding-right: 0px !important;
#  overflow-y: hidden;
# }
# a {
#  font-family: sans-serif;
#  color: #ebdbb2;
#  -webkit-font-smoothing: antialiased !important;
# }
# a:hover,
# a:focus {
#  color: #fbf1c7;
#  -webkit-font-smoothing: antialiased !important;
# }
# div#maintoolbar {
#  position: absolute;
#  width: 90%;
#  margin-left: -10%;
#  padding-right: 8%;
#  float: left;
#  background: transparent !important;
# }
# #maintoolbar {
#  margin-bottom: -3px;
#  margin-top: 0px;
#  border: 0px;
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('fcc-forum-pageviews.csv', index_col= 0)

# %%
df = df[df['value'] >= df['value'].quantile(0.025)] 
df = df[df['value'] <= df['value'].quantile(0.975)]
df
# Out:
#              value  year
# date
# 2016-06-17   21691  2016
# 2016-06-18   21681  2016
# 2016-06-20   28508  2016
# 2016-06-21   26805  2016
# 2016-06-25   21923  2016
# ...            ...   ...
# 2019-11-03  130118  2019
# 2019-11-09  115642  2019
# 2019-11-10  117717  2019
# 2019-11-16  125634  2019
# 2019-11-17  131639  2019
#
# [1177 rows x 2 columns]

# %%
df = df.copy()
a = df.index.values
df['date'] = pd.to_datetime(a)
df['year'] = [d.year for d in df.date]
#df3['year'] = [d.year for d in df_box.date]
fig,ax = plt.subplots(figsize= [12,12])
ax.plot(df['date'],df['value'], scaley=True)
ax.set(xlabel = 'Date', ylabel = 'Page Views', title = 'Daily freeCodeCamp Forum Page Views 5/2016-12/2019')
# Out:
# [Text(0.5, 0, 'Date'),
#  Text(0, 0.5, 'Page Views'),
#  Text(0.5, 1.0, 'Daily freeCodeCamp Forum Page Views 5/2016-12/2019')]

# %%
df
# Out:
#              value  year       date
# date
# 2016-06-17   21691  2016 2016-06-17
# 2016-06-18   21681  2016 2016-06-18
# 2016-06-20   28508  2016 2016-06-20
# 2016-06-21   26805  2016 2016-06-21
# 2016-06-25   21923  2016 2016-06-25
# ...            ...   ...        ...
# 2019-11-03  130118  2019 2019-11-03
# 2019-11-09  115642  2019 2019-11-09
# 2019-11-10  117717  2019 2019-11-10
# 2019-11-16  125634  2019 2019-11-16
# 2019-11-17  131639  2019 2019-11-17
#
# [1177 rows x 3 columns]

# %%
df = df1
df1.index = pd.to_datetime(df1.index)
df1 = df1.resample('M').mean()

# %%
df1 = df.resample('M').mean()
fig,ax = plt.subplots(figsize= [12,12])
'''ax.bar(precip_june_aug_2005.index.values,
       precip_june_aug_2005['DAILY_PRECIP'],
       color='purple')'''
ax.bar(df1.index.values, df1['value'], color = 'red')
ax.set(xlabel = 'Date', 
       ylabel = 'Page Views', title = 'Daily freeCodeCamp Forum Page Views 5/2016-12/2019')
# Out:
# [Text(0.5, 0, 'Date'),
#  Text(0, 0.5, 'Page Views'),
#  Text(0.5, 1.0, 'Daily freeCodeCamp Forum Page Views 5/2016-12/2019')]

# %%
df
# Out:
#                     value
# date
# 2016-05-31   19432.400000
# 2016-06-30   21875.105263
# 2016-07-31   24109.678571
# 2016-08-31   31049.193548
# 2016-09-30   41476.866667
# 2016-10-31   27398.322581
# 2016-11-30   40448.633333
# 2016-12-31   27832.419355
# 2017-01-31   32785.161290
# 2017-02-28   31113.071429
# 2017-03-31   29369.096774
# 2017-04-30   30878.733333
# 2017-05-31   34244.290323
# 2017-06-30   43577.500000
# 2017-07-31   65806.838710
# 2017-08-31   47712.451613
# 2017-09-30   47376.800000
# 2017-10-31   47438.709677
# 2017-11-30   57701.566667
# 2017-12-31   48420.580645
# 2018-01-31   58580.096774
# 2018-02-28   65679.000000
# 2018-03-31   62693.774194
# 2018-04-30   62350.833333
# 2018-05-31   56562.870968
# 2018-06-30   70117.000000
# 2018-07-31   63591.064516
# 2018-08-31   62831.612903
# 2018-09-30   65941.733333
# 2018-10-31  113663.275862
# 2018-11-30   78688.333333
# 2018-12-31   80047.483871
# 2019-01-31  102056.516129
# 2019-02-28  105968.357143
# ...

# %%
df3 = df.copy()
b = df3.index.values
df3['date'] = pd.to_datetime(b)
df3['month'] = [d.strftime('%b') for d in df3.date]
df3['year'] = [d.year for d in df3.date]
plt.figure(figsize=[12,12])
ax = sns.barplot(x='year', y="value", hue = 'month',data=df3,)

# %%
df_box = df.copy()
df_box.reset_index(inplace=True)
df_box['year'] = [d.year for d in df_box.date]
df_box['month'] = [d.strftime('%b') for d in df_box.date]

df_box
# Out:
#            date   value  year month
# 0    2016-05-19   19736  2016   May
# 1    2016-05-26   18060  2016   May
# 2    2016-05-27   19997  2016   May
# 3    2016-05-28   19044  2016   May
# 4    2016-05-29   20325  2016   May
# ...         ...     ...   ...   ...
# 1234 2019-11-24  138875  2019   Nov
# 1235 2019-11-29  171584  2019   Nov
# 1236 2019-11-30  141161  2019   Nov
# 1237 2019-12-01  142918  2019   Dec
# 1238 2019-12-03  158549  2019   Dec
#
# [1239 rows x 4 columns]

# %%
fig, axes = plt.subplots(1, 2,figsize = [12,6])
sns.boxplot(x='year', y='value',  ax=axes[0], data = df_box ).set_title("Year-wise Box Plot (Trend)" )
sns.boxplot(x='month', y='value',  ax=axes[1], data = df_box).set_title( "Month-wise Box Plot (Seasonality)")
#axes[0].title('r')
plt.show()
